# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="whitegrid")
plt.rcParams['figure.figsize']=(30,15)

# %%
data = pd.read_csv('inflation.csv')

# %%
data.head()
# Out:
#    Date  Inflation rate
# 0  1960        1.457976
# 1  1961        1.070724
# 2  1962        1.198773
# 3  1963        1.239669
# 4  1964        1.278912

# %%
sns.lineplot(data=data, x="Date", y="Inflation rate")
plt.title('Inflation rate in the USA', fontsize=30)
plt.xlabel('Years', fontsize=20)
plt.ylabel('Percent', fontsize=20)


plt.savefig('inflation_rate.png')
